# %% [markdown]
# # Importing Libraries

# %%
#Importing all the requied libraries , which I used in this Project.
import os
import pandas as pd
import pickle
import shutil
import numpy as np
import seaborn as sns
from sklearn.datasets import load_files
from keras.utils import np_utils
import matplotlib.pyplot as plt
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
from keras.callbacks import ModelCheckpoint
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix

from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

from PIL import ImageFile   
from sklearn.model_selection import train_test_split
from keras.preprocessing import image                  
from tqdm import tqdm

from keras.applications.vgg16 import VGG16

# %% [markdown]
# # Defining the train,test and model directories
#
# * We will create the directories for train,test and model training paths if not present

# %%
# That's are my model path directories 
TEST_DIR = os.path.join(os.getcwd(),"imgs","test")
TRAIN_DIR = os.path.join(os.getcwd(),"imgs","train")
MODEL_PATH = os.path.join(os.getcwd(),"model","vgg16_modified")
PICKLE_PATH = os.path.join(os.getcwd(),"pickle")
TEST_CSV = os.path.join(os.getcwd(),"csv_files","test.csv")
TRAIN_CSV = os.path.join(os.getcwd(),"csv_files","train.csv")

# %%
# Using condition to confirm that have all above defined directories are their or not .
if not os.path.exists(TEST_DIR):
    print("Testing data does not exists")
if not os.path.exists(TRAIN_DIR):
    print("Training data does not exists")
if not os.path.exists(MODEL_PATH):
    print("Model path does not exists")
    os.makedirs(MODEL_PATH)
    print("Model path created")
else:
    shutil.rmtree(MODEL_PATH)
    os.makedirs(MODEL_PATH)
if not os.path.exists(PICKLE_PATH):
    os.makedirs(PICKLE_PATH)
# Out:
# Model path does not exists
# Model path created

# %% [markdown]
# As a result, a csv file will be created containing the locations of the training and test images, and their associated classes, if present, so that the data can be traced easily.

# %%
# Use pandas library to read csv file of training and testing data set.
data_train = pd.read_csv(TRAIN_CSV)
data_test = pd.read_csv(TEST_CSV)

# %% [markdown]
# ## Converting into numerical values

# %% [markdown]
# 1 :- Using tolist() function returns a copy of the array elements as a Python list.
# 2 :- Using PKL file enabless objects to be serialized to files on disk and deserialized back into the program at runtime.
# 3 :- At the last converts a Python object hierarchy into a byte stream written to a buffer or to a disk file.

# %%
labels_list = list(set(data_train['ClassName'].values.tolist()))
labels_id = {label_name:id for id,label_name in enumerate(labels_list)}
print(labels_id)
data_train['ClassName'].replace(labels_id,inplace=True)

labels = to_categorical(data_train['ClassName'])
print(labels.shape)

with open(os.path.join(PICKLE_PATH,"labels_list_vgg16_modified.pkl"),"wb") as handle:
    pickle.dump(labels_id,handle)
# Out:
# {'c9': 0, 'c6': 1, 'c4': 2, 'c5': 3, 'c8': 4, 'c2': 5, 'c7': 6, 'c3': 7, 'c1': 8, 'c0': 9}
# (17462, 10)

# %% [markdown]
# # Data Preparation
#
# 1. Converting the all the train and test images into image size of 64,64,3
# 2. Standardizing the flattened image vector

# %%
# Spliting each data train and test into two parts . 
xtrain,xtest,ytrain,ytest = train_test_split(data_train.iloc[:,0],labels,test_size = 0.2,random_state=42)
def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(64, 64))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
# Using library function ImageFile to make file or directory situable for pictures. 
ImageFile.LOAD_TRUNCATED_IMAGES = True                 
# pre-process the data for Keras
train_tensors = paths_to_tensor(xtrain).astype('float32')/255 - 0.5
valid_tensors = paths_to_tensor(xtest).astype('float32')/255 - 0.5
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 13969/13969 [07:09<00:00, 32.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 3493/3493 [01:19<00:00, 43.78it/s]

# %% [markdown]
# # MODEL ARCHITECTURE

# %%
model = VGG16(include_top=False)
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Predicting model at both train and valid with single single animated progress bar 
train_vgg16 = model.predict(train_tensors,verbose=1)
valid_vgg16 = model.predict(valid_tensors,verbose=1)
# Out:
# 437/437 [==============================] - 531s 1s/step
# 110/110 [==============================] - 132s 1s/step

# %%
print("Train shape",train_vgg16.shape)
print("Validation shape",valid_vgg16.shape)
# Out:
# Train shape (13969, 2, 2, 512)
# Validation shape (3493, 2, 2, 512)

# %%
train_features = train_vgg16[0]
valid_features = valid_vgg16[0]

# %%
print("Train features shape",train_features.shape)
print("Validation features shape",valid_features.shape)
# Out:
# Train features shape (2, 2, 512)
# Validation features shape (2, 2, 512)

# %% [markdown]
# # Model Architecture

# %%
# To create a model layer-by-layer.
vgg16_model_modified = Sequential()
# Used vgg16_model_modified instead of vgg16_model for better experience 
vgg16_model_modified.add(Flatten(input_shape=train_features.shape))
# Adding an extra Dense layer from 10 to 500 ,activation from softmax to relu.
vgg16_model_modified.add(Dense(500, activation='relu',kernel_initializer='glorot_normal'))
vgg16_model_modified.add(Dropout(0.5))
vgg16_model_modified.add(Dense(10, activation='softmax',kernel_initializer='glorot_normal'))

vgg16_model_modified.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 500)               1024500
# _________________________________________________________________
# dropout (Dropout)            (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 1,029,510
# Trainable params: 1,029,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
# In this step I have convert python code from string form to code object. 
vgg16_model_modified.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
plot_model(vgg16_model_modified,to_file=os.path.join(os.getcwd(),"model","vgg16","model_distracted_driver_vgg16.png"),show_shapes=True,show_layer_names=True)

# %%
# Create a path to save the check point 
filepath = os.path.join(MODEL_PATH,"distracted-{epoch:02d}-{val_accuracy:.2f}.hdf5")
# Creating chekpoint to save and source control combined into a single package.
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max',period=1)
callbacks_list = [checkpoint]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
model_history = vgg16_model_modified.fit(train_vgg16,ytrain,validation_data = (valid_vgg16, ytest),epochs=75, batch_size=16, shuffle=True,callbacks=callbacks_list)
# Out:
# Epoch 1/75
# 872/874 [============================>.] - ETA: 0s - loss: 1.1251 - accuracy: 0.6177
# Epoch 00001: val_accuracy improved from -inf to 0.85170, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-01-0.85.hdf5
# 874/874 [==============================] - 22s 25ms/step - loss: 1.1241 - accuracy: 0.6180 - val_loss: 0.4496 - val_accuracy: 0.8517
# Epoch 2/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.5152 - accuracy: 0.8330
# Epoch 00002: val_accuracy improved from 0.85170 to 0.90782, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-02-0.91.hdf5
# 874/874 [==============================] - 23s 26ms/step - loss: 0.5151 - accuracy: 0.8331 - val_loss: 0.2675 - val_accuracy: 0.9078
# Epoch 3/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.3739 - accuracy: 0.8788
# Epoch 00003: val_accuracy improved from 0.90782 to 0.92757, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-03-0.93.hdf5
# 874/874 [==============================] - 22s 25ms/step - loss: 0.3739 - accuracy: 0.8788 - val_loss: 0.2486 - val_accuracy: 0.9276
# Epoch 4/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.3222 - accuracy: 0.9002
# Epoch 00004: val_accuracy improved from 0.92757 to 0.96278, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-04-0.96.hdf5
# 874/874 [==============================] - 23s 26ms/step - loss: 0.3223 - accuracy: 0.9002 - val_loss: 0.1376 - val_accuracy: 0.9628
# Epoch 5/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.2694 - accuracy: 0.9165
# Epoch 00005: val_accuracy did not improve from 0.96278
# 874/874 [==============================] - 22s 25ms/step - loss: 0.2694 - accuracy: 0.9165 - val_loss: 0.1963 - val_accuracy: 0.9433
# Epoch 6/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.2594 - accuracy: 0.9255
# Epoch 00006: val_accuracy improved from 0.96278 to 0.96507, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-06-0.97.hdf5
# 874/874 [==============================] - 23s 26ms/step - loss: 0.2591 - accuracy: 0.9255 - val_loss: 0.1278 - val_accuracy: 0.9651
# Epoch 7/75
# 874/874 [==============================] - ETA: 0s - loss: 0.2431 - accuracy: 0.9280
# Epoch 00007: val_accuracy did not improve from 0.96507
# 874/874 [==============================] - 23s 26ms/step - loss: 0.2431 - accuracy: 0.9280 - val_loss: 0.1696 - val_accuracy: 0.9510
# Epoch 8/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.2271 - accuracy: 0.9338
# Epoch 00008: val_accuracy did not improve from 0.96507
# 874/874 [==============================] - 23s 26ms/step - loss: 0.2271 - accuracy: 0.9339 - val_loss: 0.1705 - val_accuracy: 0.9551
# Epoch 9/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.2109 - accuracy: 0.9404
# Epoch 00009: val_accuracy improved from 0.96507 to 0.96679, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-09-0.97.hdf5
# 874/874 [==============================] - 23s 27ms/step - loss: 0.2110 - accuracy: 0.9404 - val_loss: 0.1276 - val_accuracy: 0.9668
# Epoch 10/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.2122 - accuracy: 0.9428 ETA: 0s - loss: 0.2113 - accuracy:
# Epoch 00010: val_accuracy improved from 0.96679 to 0.97023, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-10-0.97.hdf5
# 874/874 [==============================] - 23s 26ms/step - loss: 0.2122 - accuracy: 0.9428 - val_loss: 0.1183 - val_accuracy: 0.9702
# Epoch 11/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.2026 - accuracy: 0.9458
# Epoch 00011: val_accuracy did not improve from 0.97023
# 874/874 [==============================] - 22s 25ms/step - loss: 0.2025 - accuracy: 0.9458 - val_loss: 0.1731 - val_accuracy: 0.9588
# Epoch 12/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.2018 - accuracy: 0.9471
# Epoch 00012: val_accuracy improved from 0.97023 to 0.97452, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-12-0.97.hdf5
# 874/874 [==============================] - 22s 25ms/step - loss: 0.2018 - accuracy: 0.9471 - val_loss: 0.1154 - val_accuracy: 0.9745
# Epoch 13/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1939 - accuracy: 0.9508
# Epoch 00013: val_accuracy did not improve from 0.97452
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1939 - accuracy: 0.9508 - val_loss: 0.1097 - val_accuracy: 0.9734
# Epoch 14/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1945 - accuracy: 0.9495
# Epoch 00014: val_accuracy did not improve from 0.97452
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1945 - accuracy: 0.9495 - val_loss: 0.1275 - val_accuracy: 0.9674
# Epoch 15/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9542
# Epoch 00015: val_accuracy did not improve from 0.97452
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1853 - accuracy: 0.9542 - val_loss: 0.1628 - val_accuracy: 0.9614
# Epoch 16/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1830 - accuracy: 0.9550
# Epoch 00016: val_accuracy did not improve from 0.97452
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1837 - accuracy: 0.9549 - val_loss: 0.1142 - val_accuracy: 0.9719
# Epoch 17/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9598
# Epoch 00017: val_accuracy did not improve from 0.97452
# 874/874 [==============================] - 22s 26ms/step - loss: 0.1753 - accuracy: 0.9598 - val_loss: 0.1281 - val_accuracy: 0.9722
# Epoch 18/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9594
# Epoch 00018: val_accuracy improved from 0.97452 to 0.97881, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-18-0.98.hdf5
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1625 - accuracy: 0.9594 - val_loss: 0.1111 - val_accuracy: 0.9788
# Epoch 19/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1649 - accuracy: 0.9593
# Epoch 00019: val_accuracy did not improve from 0.97881
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1649 - accuracy: 0.9593 - val_loss: 0.1457 - val_accuracy: 0.9760
# Epoch 20/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1586 - accuracy: 0.9626
# Epoch 00020: val_accuracy did not improve from 0.97881
# 874/874 [==============================] - 21s 24ms/step - loss: 0.1590 - accuracy: 0.9626 - val_loss: 0.1439 - val_accuracy: 0.9705
# Epoch 21/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9623
# Epoch 00021: val_accuracy did not improve from 0.97881
# 874/874 [==============================] - 21s 24ms/step - loss: 0.1689 - accuracy: 0.9623 - val_loss: 0.0977 - val_accuracy: 0.9788
# Epoch 22/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1592 - accuracy: 0.9619
# Epoch 00022: val_accuracy did not improve from 0.97881
# 874/874 [==============================] - 21s 24ms/step - loss: 0.1594 - accuracy: 0.9619 - val_loss: 0.1114 - val_accuracy: 0.9777
# Epoch 23/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1611 - accuracy: 0.9629
# Epoch 00023: val_accuracy did not improve from 0.97881
# 874/874 [==============================] - 22s 26ms/step - loss: 0.1610 - accuracy: 0.9629 - val_loss: 0.1175 - val_accuracy: 0.9751
# Epoch 24/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9636
# Epoch 00024: val_accuracy improved from 0.97881 to 0.97910, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-24-0.98.hdf5
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1543 - accuracy: 0.9636 - val_loss: 0.1153 - val_accuracy: 0.9791
# Epoch 25/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1555 - accuracy: 0.9644
# Epoch 00025: val_accuracy did not improve from 0.97910
# 874/874 [==============================] - 21s 24ms/step - loss: 0.1555 - accuracy: 0.9644 - val_loss: 0.1347 - val_accuracy: 0.9754
# Epoch 26/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1397 - accuracy: 0.9673
# Epoch 00026: val_accuracy did not improve from 0.97910
# 874/874 [==============================] - 21s 24ms/step - loss: 0.1397 - accuracy: 0.9673 - val_loss: 0.1811 - val_accuracy: 0.9662
# Epoch 27/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9689
# Epoch 00027: val_accuracy did not improve from 0.97910
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1352 - accuracy: 0.9689 - val_loss: 0.2169 - val_accuracy: 0.9642
# Epoch 28/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1359 - accuracy: 0.9681
# Epoch 00028: val_accuracy did not improve from 0.97910
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1359 - accuracy: 0.9681 - val_loss: 0.1427 - val_accuracy: 0.9777
# Epoch 29/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1511 - accuracy: 0.9689
# Epoch 00029: val_accuracy improved from 0.97910 to 0.97939, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-29-0.98.hdf5
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1511 - accuracy: 0.9689 - val_loss: 0.1328 - val_accuracy: 0.9794
# Epoch 30/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1485 - accuracy: 0.9671
# Epoch 00030: val_accuracy did not improve from 0.97939
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1485 - accuracy: 0.9671 - val_loss: 0.1345 - val_accuracy: 0.9777
# Epoch 31/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1419 - accuracy: 0.9668
# Epoch 00031: val_accuracy improved from 0.97939 to 0.97967, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-31-0.98.hdf5
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1419 - accuracy: 0.9668 - val_loss: 0.1338 - val_accuracy: 0.9797
# Epoch 32/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1437 - accuracy: 0.9705
# Epoch 00032: val_accuracy did not improve from 0.97967
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1439 - accuracy: 0.9704 - val_loss: 0.1062 - val_accuracy: 0.9785
# Epoch 33/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9695
# Epoch 00033: val_accuracy did not improve from 0.97967
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1347 - accuracy: 0.9695 - val_loss: 0.1420 - val_accuracy: 0.9771
# Epoch 34/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1400 - accuracy: 0.9682
# Epoch 00034: val_accuracy did not improve from 0.97967
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1400 - accuracy: 0.9682 - val_loss: 0.1237 - val_accuracy: 0.9791
# Epoch 35/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1338 - accuracy: 0.9729
# Epoch 00035: val_accuracy did not improve from 0.97967
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1338 - accuracy: 0.9729 - val_loss: 0.1693 - val_accuracy: 0.9768
# Epoch 36/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1516 - accuracy: 0.9697
# Epoch 00036: val_accuracy did not improve from 0.97967
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1516 - accuracy: 0.9697 - val_loss: 0.1440 - val_accuracy: 0.9777
# Epoch 37/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1242 - accuracy: 0.9725
# Epoch 00037: val_accuracy improved from 0.97967 to 0.98225, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-37-0.98.hdf5
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1242 - accuracy: 0.9725 - val_loss: 0.1302 - val_accuracy: 0.9823
# Epoch 38/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1329 - accuracy: 0.9731
# Epoch 00038: val_accuracy did not improve from 0.98225
# 874/874 [==============================] - 22s 26ms/step - loss: 0.1328 - accuracy: 0.9731 - val_loss: 0.1228 - val_accuracy: 0.9814
# Epoch 39/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9729
# Epoch 00039: val_accuracy did not improve from 0.98225
# 874/874 [==============================] - 23s 26ms/step - loss: 0.1236 - accuracy: 0.9729 - val_loss: 0.1408 - val_accuracy: 0.9811
# Epoch 40/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9722
# Epoch 00040: val_accuracy improved from 0.98225 to 0.98311, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-40-0.98.hdf5
# 874/874 [==============================] - 23s 27ms/step - loss: 0.1272 - accuracy: 0.9722 - val_loss: 0.1157 - val_accuracy: 0.9831
# Epoch 41/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9737
# Epoch 00041: val_accuracy did not improve from 0.98311
# 874/874 [==============================] - 22s 26ms/step - loss: 0.1319 - accuracy: 0.9737 - val_loss: 0.1363 - val_accuracy: 0.9817
# Epoch 42/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1343 - accuracy: 0.9748
# Epoch 00042: val_accuracy did not improve from 0.98311
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1343 - accuracy: 0.9748 - val_loss: 0.1201 - val_accuracy: 0.9814
# Epoch 43/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9759
# Epoch 00043: val_accuracy did not improve from 0.98311
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1226 - accuracy: 0.9759 - val_loss: 0.1299 - val_accuracy: 0.9820
# Epoch 44/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1406 - accuracy: 0.9745
# Epoch 00044: val_accuracy did not improve from 0.98311
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1406 - accuracy: 0.9745 - val_loss: 0.1086 - val_accuracy: 0.9828
# Epoch 45/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1330 - accuracy: 0.9751
# Epoch 00045: val_accuracy did not improve from 0.98311
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1330 - accuracy: 0.9751 - val_loss: 0.1594 - val_accuracy: 0.9802
# Epoch 46/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1336 - accuracy: 0.9748
# Epoch 00046: val_accuracy improved from 0.98311 to 0.98683, saving model to C:\Users\Engr Amir\Downloads\Distracted-Driver-Detection-master\model\vgg16_modified\distracted-46-0.99.hdf5
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1335 - accuracy: 0.9748 - val_loss: 0.1115 - val_accuracy: 0.9868
# Epoch 47/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1249 - accuracy: 0.9763
# Epoch 00047: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1248 - accuracy: 0.9763 - val_loss: 0.1197 - val_accuracy: 0.9868
# Epoch 48/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.9759
# Epoch 00048: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1323 - accuracy: 0.9759 - val_loss: 0.1298 - val_accuracy: 0.9814
# Epoch 49/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1165 - accuracy: 0.9767
# Epoch 00049: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1165 - accuracy: 0.9767 - val_loss: 0.1615 - val_accuracy: 0.9811
# Epoch 50/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9762
# Epoch 00050: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1171 - accuracy: 0.9762 - val_loss: 0.1415 - val_accuracy: 0.9845
# Epoch 51/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9769
# Epoch 00051: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1169 - accuracy: 0.9769 - val_loss: 0.1467 - val_accuracy: 0.9814
# Epoch 52/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1289 - accuracy: 0.9767
# Epoch 00052: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 21s 25ms/step - loss: 0.1289 - accuracy: 0.9767 - val_loss: 0.1332 - val_accuracy: 0.9840
# Epoch 53/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9789
# Epoch 00053: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 21s 24ms/step - loss: 0.1216 - accuracy: 0.9789 - val_loss: 0.1505 - val_accuracy: 0.9840
# Epoch 54/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1193 - accuracy: 0.9780
# Epoch 00054: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 21s 24ms/step - loss: 0.1192 - accuracy: 0.9780 - val_loss: 0.1484 - val_accuracy: 0.9831
# Epoch 55/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9771
# Epoch 00055: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 21s 25ms/step - loss: 0.1231 - accuracy: 0.9771 - val_loss: 0.1433 - val_accuracy: 0.9860
# Epoch 56/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1261 - accuracy: 0.9767
# Epoch 00056: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1261 - accuracy: 0.9767 - val_loss: 0.1571 - val_accuracy: 0.9805
# Epoch 57/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1176 - accuracy: 0.9807
# Epoch 00057: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1176 - accuracy: 0.9807 - val_loss: 0.2025 - val_accuracy: 0.9802
# Epoch 58/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9795
# Epoch 00058: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 26ms/step - loss: 0.1102 - accuracy: 0.9795 - val_loss: 0.1653 - val_accuracy: 0.9788
# Epoch 59/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9782
# Epoch 00059: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1295 - accuracy: 0.9782 - val_loss: 0.1584 - val_accuracy: 0.9843
# Epoch 60/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9801
# Epoch 00060: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1093 - accuracy: 0.9801 - val_loss: 0.1562 - val_accuracy: 0.9825
# Epoch 61/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9800
# Epoch 00061: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1159 - accuracy: 0.9800 - val_loss: 0.1453 - val_accuracy: 0.9802
# Epoch 62/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1175 - accuracy: 0.9794
# Epoch 00062: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1174 - accuracy: 0.9793 - val_loss: 0.1546 - val_accuracy: 0.9831
# Epoch 63/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1184 - accuracy: 0.9798
# Epoch 00063: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1183 - accuracy: 0.9798 - val_loss: 0.1491 - val_accuracy: 0.9831
# Epoch 64/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9790
# Epoch 00064: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1260 - accuracy: 0.9790 - val_loss: 0.1650 - val_accuracy: 0.9768
# Epoch 65/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9777
# Epoch 00065: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1207 - accuracy: 0.9777 - val_loss: 0.1536 - val_accuracy: 0.9828
# Epoch 66/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1352 - accuracy: 0.9777
# Epoch 00066: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1352 - accuracy: 0.9777 - val_loss: 0.1599 - val_accuracy: 0.9831
# Epoch 67/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1328 - accuracy: 0.9772
# Epoch 00067: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1328 - accuracy: 0.9772 - val_loss: 0.2076 - val_accuracy: 0.9777
# Epoch 68/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.9800
# Epoch 00068: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 26ms/step - loss: 0.1209 - accuracy: 0.9800 - val_loss: 0.1960 - val_accuracy: 0.9831
# Epoch 69/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1193 - accuracy: 0.9790
# Epoch 00069: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1191 - accuracy: 0.9790 - val_loss: 0.1611 - val_accuracy: 0.9800
# Epoch 70/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1107 - accuracy: 0.9822
# Epoch 00070: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1105 - accuracy: 0.9822 - val_loss: 0.1457 - val_accuracy: 0.9860
# Epoch 71/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9827
# Epoch 00071: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1116 - accuracy: 0.9827 - val_loss: 0.1715 - val_accuracy: 0.9837
# Epoch 72/75
# 872/874 [============================>.] - ETA: 0s - loss: 0.1171 - accuracy: 0.9807
# Epoch 00072: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 23s 27ms/step - loss: 0.1172 - accuracy: 0.9807 - val_loss: 0.1540 - val_accuracy: 0.9845
# Epoch 73/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9827
# Epoch 00073: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1095 - accuracy: 0.9827 - val_loss: 0.1763 - val_accuracy: 0.9820
# Epoch 74/75
# 874/874 [==============================] - ETA: 0s - loss: 0.1069 - accuracy: 0.9810
# Epoch 00074: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1069 - accuracy: 0.9810 - val_loss: 0.1975 - val_accuracy: 0.9805
# Epoch 75/75
# 873/874 [============================>.] - ETA: 0s - loss: 0.1137 - accuracy: 0.9808
# Epoch 00075: val_accuracy did not improve from 0.98683
# 874/874 [==============================] - 22s 25ms/step - loss: 0.1137 - accuracy: 0.9808 - val_loss: 0.1520 - val_accuracy: 0.9857

# %%
# displayed comparatively result of train and validation data 
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(model_history.history['loss'], color='b', label="Training loss")
ax1.plot(model_history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, 75, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(model_history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(model_history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, 75, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Analysis
# Finding the Confusion matrix,Precision,Recall and F1 score to analyse the model thus created

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    fig.savefig(os.path.join(MODEL_PATH,"confusion_matrix.png"))
    return fig

# %%
def print_heatmap(n_labels, n_predictions, class_names):
    labels = n_labels #sess.run(tf.argmax(n_labels, 1))
    predictions = n_predictions #sess.run(tf.argmax(n_predictions, 1))

#     confusion_matrix = sess.run(tf.contrib.metrics.confusion_matrix(labels, predictions))
    matrix = confusion_matrix(labels.argmax(axis=1),predictions.argmax(axis=1))
    row_sum = np.sum(matrix, axis = 1)
    w, h = matrix.shape

    c_m = np.zeros((w, h))

    for i in range(h):
        c_m[i] = matrix[i] * 100 / row_sum[i]

    c = c_m.astype(dtype = np.uint8)

    
    heatmap = print_confusion_matrix(c, class_names, figsize=(18,10), fontsize=20)

# %%
class_names = list()
for name,idx in labels_id.items():
    class_names.append(name)
# print(class_names)
ypred = vgg16_model_modified.predict(valid_vgg16,verbose=1)
# Out:
# 110/110 [==============================] - 0s 4ms/step

# %% [markdown]
# ## Confusion Matrix

# %%
# Pridicting the accuracy of model by ploting heatmap for True and predicted labels 
print_heatmap(ytest,ypred,class_names)

# %% [markdown]
# # Precision Recall F1 Score

# %%
ypred_class = np.argmax(ypred,axis=1)
# print(ypred_class[:10])
ytest = np.argmax(ytest,axis=1)

# %%
accuracy = accuracy_score(ytest,ypred_class)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(ytest, ypred_class,average='weighted')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(ytest,ypred_class,average='weighted')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(ytest,ypred_class,average='weighted')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.985686
# Precision: 0.985768
# Recall: 0.985686
# F1 score: 0.985695
